# %% [markdown]
# The purpose of the file is to create a recommendation engine that allows PWD to get top 5 relevant jobs based on its skills and disability.

# %%
#Libraries
import math
from collections import Counter
from nltk import cluster
from scipy import spatial
import operator
import pandas as pd
import numpy as np 
import re

# %%
jdskill=pd.read_csv('JDToSkills.csv',encoding='latin-1')
jdskill
# Out:
#                                               jobTitle  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3            Graduate Studies Program - Data Scientist
# 4                                     Data Scientist I
# ...                                                ...
# 1042                          Accessibility Consultant
# 1043                        Customer Support Executive
# 1044        Customer Support Executive - Email Support
# 1045  Customer Support Executive - Grievance Redressal
# 1046                           Customer Support (Chat)
#
#                              company  \
# 0                    Express Scripts
# 1      Money Mart Financial Services
# 2                           comScore
# 3        Central Intelligence Agency
# 4     Federal Reserve Bank of Dallas
# ...                              ...
# 1042                Oracle, SAP Labs
# 1043                             IBM
# 1044                          Allsec
# 1045                         Hyundai
# 1046                          VMWare
#
#                                                    desc  \
# 0     position summary, the business analyst role is...
# 1     what do we need?, you to have an amazing perso...
# 2     validate, analyze, and conduct statistical ana...
# 3     full time, washington, dc metro area, starting...
# 4     assist in consultations with business partners...
# ...                                                 ...
# 1042  Ensure that software developed meets the acces...
# 1043  Talk to customers and clients to fulfil given ...
# 1044  Comprehend the customer's mail and respond acc...
# 1045  Understand customer complaints, capture missin...
# 1046  Troubleshoot hardware and software issues on v...
#
#                                                  Skills  \
# 0     ['a critical requirement', 'product aesthetics...
# 1     ['fosters employee growth', 'segmentation', 'r...
# 2     ['analytical software excel', 'sql', 'effectiv...
# 3     ['shape technology', 'advanced hardware', 'com...
# 4     ['internal/external hr', 'hr dashboards', 'met...
# ...                                                 ...
# 1042  ['accessibility', 'of accessibility', 'quality...
# 1043  ['customer handling', 'ms excel', 'reading', '...
# 1044  ['computer skills','typing','ms excel','custom...
# 1045  ['computer skills','typing','communication ski...
# 1046  ['computer skills',typing','domain knowledge',...
#
#                                              Disability
# 0     Spinal Cord Injury, Leprosoy Cured persons, Au...
# 1     Spinal Cord Injury, Leprosoy Cured persons, Au...
# 2     Spinal Cord Injury, Leprosoy Cured persons, Au...
# 3     Parkinson's disease, Multiple Sclerosis, Muscu...
# 4                     Spinal Cord Injury, Schizophrenia
# ...                                                 ...
# 1042  Physical Disability,Low Vision,Hearing Impairm...
# 1043  Physical Disability,Low Vision,Hearing Impairm...
# 1044  Physical Disability,Low Vision,Hearing Impairm...
# 1045  Physical Disability,Low Vision,Hearing Impairm...
# 1046  Physical Disability,Low Vision,Hearing Impairm...
#
# [1047 rows x 5 columns]

# %%
profileskill=pd.read_csv('ProfileToSkills.csv',encoding='cp1252')
profileskill
# Out:
#                                name          disability  \
# 0                       Ratul Arora           Blindness
# 1                        Aman Verma          Low Vision
# 2                       Sampa Gupta           Blindness
# 3                        Monu Varma           Blindness
# 4               Jayant Singh Raghav           Blindness
# ...                             ...                 ...
# 1052                  Resham Talwar           Blindness
# 1053                Sachin J Shetty  Muscular Dystrophy
# 1054  Chaitanya Purushottam Kayande           Blindness
# 1055                  Pulkit Sharma      Cerebral Palsy
# 1056                    Nisha Tayal           Blindness
#
#                                                     bio  \
# 0     ratul arora is from delhi. he has blindness. h...
# 1     aman verma is from nalasopara, maharashtra. he...
# 2     sampa gupta is from mumbai, maharashtra. she h...
# 3     monu varma is a 29-year-old visually impaired ...
# 4     jayant singh raghav believes that the position...
# ...                                                 ...
# 1052  reshams life has not been easy. she thinks tha...
# 1053  sachin shetty belongs to the city of dreams an...
# 1054  chaitanya was born with complete blindness and...
# 1055  pulkit sharma is a fun-loving person who is di...
# 1056  nisha tayal, a graduate in economics, is a vis...
#
#                                                  Skills
# 0     ['the accessibility', 'domain', 'a test engine...
# 1     ['aman verma', 'an accessibility tester', 'an ...
# 2     ['a certified dhs', 'tester', 'accessibility s...
# 3     ['computer applications', 'hcl technologies', ...
# 4     ['time management', 'team leadership', 'a stro...
# ...                                                 ...
# 1052  ['braille', 'a born-to-be voice-over artist', ...
# 1053  ['stories', 'a good listener', 'digital conten...
# 1054  ['a tourist guide', 'co-curricular skills', 'm...
# 1055  ['a fun-loving person', 'voiceover', 'mimicry'...
# 1056  ['economics', 'a voice-over artist', 'retina p...
#
# [1057 rows x 4 columns]

# %%
#function to clean data
def clean_text(raw):
    '''Case specific to be used with pandas apply method'''
    try:
        # remove carriage returns and new lines
        raw = raw.replace('\r', '')
        raw = raw.replace('\n', '')
        
        # brackets appear in all instances
        raw = raw.replace('[', '')
        raw = raw.replace(']', '')
        raw = raw.replace(')', '')
        raw = raw.replace('(', '')
        
        # removing html tags
        clean_html = re.compile('<.*?>')
        clean_text = re.sub(clean_html, ' ', raw)
        
        # removing duplicate whitespace in between words
        clean_text = re.sub(" +", " ", clean_text) 
        
        # stripping first and last white space 
        clean_text = clean_text.strip()
        
        # commas had multiple spaces before and after in each instance
        clean_text = re.sub(" , ", ", ", clean_text) 
        clean_text = re.sub(", ", ",", clean_text) 
        
        # eliminating the extra comma after a period
        clean_text = clean_text.replace('.,', '.')
        
        # using try and except due to Nan in the column
    except:
        clean_text = np.nan
        
    return clean_text

# %%
#get array of skills from String
def getSkillArray(arr):
    arrSplit=arr.split(",")
    newArr=[]
    for i in arrSplit:
        i=clean_text(i)
        newArr.append(i)    
    return newArr

# %%
#Get jobs based on disability of the user
def returnDF(userProfile,df):
    getIndex=[]
    disability=userProfile['disability']
    for index, row in df.iterrows():
        if len(row['Disability'])>0:
            if disability in row['Disability']:
                getIndex.append(index)
    newTestDf=jdskill.iloc[getIndex]
    return newTestDf

# %%
#Recommendation Engine
class remommendationModel:
    def __init__(self, skills, df):
        self.dataframe = df
        self.skill_set = skills
        
    def recommendation_vectors(self):
        final_list = []
        #test1=self.skill_set
        skillArray1=getSkillArray(self.skill_set)
        counter1 = Counter(skillArray1)
        for index, row in self.dataframe.iterrows():
            if(len(row['Skills']) > 0):
                skillArray2=getSkillArray(row['Skills'])
                counter2 = Counter(skillArray2)
                all_items = set(counter1.keys()).union( set(counter2.keys()) )
                vector1 = [counter1[k] for k in all_items]
                vector2 = [counter2[k] for k in all_items]
                similarity = 1 - spatial.distance.cosine(vector1, vector2)
                if(similarity > 0):
                    #similarity = cluster.util.cosine_distance(vector1,vector2)
                    new_dict = [row['jobTitle'], row['company'], row['Skills'],row['Disability'],similarity]
                    final_list.append(new_dict)
        return final_list

# %%
#Loading user profile and getting jobs based on disability type of the user
userProfile=profileskill.iloc[515]#429,54
finalDF=returnDF(userProfile,jdskill)

# %%
#Getting top 5 relevant jobs based of Disability type and Skills of the user
model_class = remommendationModel(userProfile['Skills'], finalDF)
recommendation_df = model_class.recommendation_vectors()
recommendation_df = sorted(recommendation_df, key=lambda x: x[4], reverse=True)
filtered_profiles = pd.DataFrame(recommendation_df, columns=['jobTitle', 'company', 'Skills','Disability','similarity'])
relevent_profiles = filtered_profiles[['jobTitle', 'company', 'Skills','Disability']]
print("Recommendation for",userProfile['name'])
print("Skills for",userProfile['Skills'])
relevent_profiles.head(5)
# Out:
# Recommendation for Chain Singh Rajpurohit
# Skills for ['customer handling', 'ms excel', 'good communication skills', 'hindi', 'rajasthani.chain singh', 'a quick learner', 'of arts', 'of customer handling bills', 'good communication skills', 'hindi', 'rajasthani.chain singh', 'quick learner', 'on new responsibilities', 'computer skills','domain knowledge','typing']
#                                            jobTitle   company  \
# 0                        Customer Support Executive       IBM
# 1        Customer Support Executive - Email Support    Allsec
# 2                           Customer Support (Chat)    VMWare
# 3  Customer Support Executive - Grievance Redressal   Hyundai
# 4                               Data Entry Operator  ANZ Bank
#
#                                               Skills  \
# 0  ['customer handling', 'ms excel', 'reading', '...
# 1  ['computer skills','typing','ms excel','custom...
# 2  ['computer skills',typing','domain knowledge',...
# 3  ['computer skills','typing','communication ski...
# 4  ['data entry', 'content writing', 'ms office'o...
#
#                                           Disability
# 0  Physical Disability,Low Vision,Hearing Impairm...
# 1  Physical Disability,Low Vision,Hearing Impairm...
# 2  Physical Disability,Low Vision,Hearing Impairm...
# 3  Physical Disability,Low Vision,Hearing Impairm...
# 4  Low Vision,Hearing Impairment (Deaf and Hard o...
